# %%
for i in range(3):
    print(f"i = {i}")
    for j in range(2):
        print(f"   j = {j}")
    print()
# Out:
# i = 0
#    j = 0
#    j = 1
#
# i = 1
#    j = 0
#    j = 1
#
# i = 2
#    j = 0
#    j = 1
